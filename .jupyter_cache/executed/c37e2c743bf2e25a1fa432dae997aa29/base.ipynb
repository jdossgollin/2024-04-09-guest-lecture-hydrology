# %%
import IJulia

# The julia kernel has built in support for Revise.jl, so this is the 
# recommended approach for long-running sessions:
# https://github.com/JuliaLang/IJulia.jl/blob/9b10fa9b879574bbf720f5285029e07758e50a5e/src/kernel.jl#L46-L51

# Users should enable revise within .julia/config/startup_ijulia.jl:
# https://timholy.github.io/Revise.jl/stable/config/#Using-Revise-automatically-within-Jupyter/IJulia-1

# clear console history
IJulia.clear_history()

fig_width = 10
fig_height = 5
fig_format = :retina
fig_dpi = 96

# no retina format type, use svg for high quality type/marks
if fig_format == :retina
  fig_format = :svg
elseif fig_format == :pdf
  fig_dpi = 96
  # Enable PDF support for IJulia
  IJulia.register_mime(MIME("application/pdf"))
end

# convert inches to pixels
fig_width = fig_width * fig_dpi
fig_height = fig_height * fig_dpi

# Intialize Plots w/ default fig width/height
try
  import Plots

  # Plots.jl doesn't support PDF output for versions < 1.28.1
  # so use png (if the DPI remains the default of 300 then set to 96)
  if (Plots._current_plots_version < v"1.28.1") & (fig_format == :pdf)
    Plots.gr(size=(fig_width, fig_height), fmt = :png, dpi = fig_dpi)
  else
    Plots.gr(size=(fig_width, fig_height), fmt = fig_format, dpi = fig_dpi)
  end
catch e
  # @warn "Plots init" exception=(e, catch_backtrace())
end

# Initialize CairoMakie with default fig width/height
try
  import CairoMakie

  # CairoMakie's display() in PDF format opens an interactive window
  # instead of saving to the ipynb file, so we don't do that.
  # https://github.com/quarto-dev/quarto-cli/issues/7548
  if fig_format == :pdf
    CairoMakie.activate!(type = "png")
  else
    CairoMakie.activate!(type = string(fig_format))
  end
  CairoMakie.update_theme!(resolution=(fig_width, fig_height))
catch e
    # @warn "CairoMakie init" exception=(e, catch_backtrace())
end
  
# Set run_path if specified
try
  run_path = raw"/Users/jamesdoss-gollin/Documents/quarto-presentations/2024-04-09-guest-lecture-hydrology"
  if !isempty(run_path)
    cd(run_path)
  end
catch e
  @warn "Run path init:" exception=(e, catch_backtrace())
end


# emulate old Pkg.installed beahvior, see
# https://discourse.julialang.org/t/how-to-use-pkg-dependencies-instead-of-pkg-installed/36416/9
import Pkg
function isinstalled(pkg::String)
  any(x -> x.name == pkg && x.is_direct_dep, values(Pkg.dependencies()))
end

# ojs_define
if isinstalled("JSON") && isinstalled("DataFrames")
  import JSON, DataFrames
  global function ojs_define(; kwargs...)
    convert(x) = x
    convert(x::DataFrames.AbstractDataFrame) = Tables.rows(x)
    content = Dict("contents" => [Dict("name" => k, "value" => convert(v)) for (k, v) in kwargs])
    tag = "<script type='ojs-define'>$(JSON.json(content))</script>"
    IJulia.display(MIME("text/html"), tag)
  end
elseif isinstalled("JSON")
  import JSON
  global function ojs_define(; kwargs...)
    content = Dict("contents" => [Dict("name" => k, "value" => v) for (k, v) in kwargs])
    tag = "<script type='ojs-define'>$(JSON.json(content))</script>"
    IJulia.display(MIME("text/html"), tag)
  end
else
  global function ojs_define(; kwargs...)
    @warn "JSON package not available. Please install the JSON.jl package to use ojs_define."
  end
end


# don't return kernel dependencies (b/c Revise should take care of dependencies)
nothing

# %%
#| output: false
#| echo: false
using DataFrames
using Extremes
using Gadfly

# %%
#| code-fold: true
data = Extremes.dataset("portpirie")
fm = gevfit(data, :SeaLevel)

p1 = plot(data, x=:Year, y=:SeaLevel, Geom.point, Geom.line, Guide.title("Port Pirie sea level"))
p2 = returnlevelplotci(fm, 0.05)
draw(SVG(9inch, 6inch), hstack(p1, p2))
# Out:
# SVG(228.6mm, 152.39999999999998mm, IOBuffer(data=UInt8[...], readable=true, writable=true, seekable=true, append=false, size=116268, maxsize=Inf, ptr=116269, mark=-1), nothing, "img-bfe74735", 0, Compose.SVGPropertyFrame[], Dict{Type, Union{Nothing, Compose.Property}}(Compose.Property{Compose.FontPrimitive} => nothing, Compose.Property{Compose.FillPrimitive} => nothing, Compose.Property{Compose.FillOpacityPrimitive} => nothing, Compose.Property{Compose.StrokePrimitive} => nothing, Compose.Property{Compose.JSCallPrimitive} => nothing, Compose.Property{Compose.FontSizePrimitive} => nothing, Compose.Property{Compose.JSIncludePrimitive} => nothing, Compose.Property{Compose.SVGAttributePrimitive} => nothing, Compose.Property{Compose.SVGClassPrimitive} => nothing, Compose.Property{Compose.StrokeDashPrimitive} => nothing…), OrderedCollections.OrderedDict{Compose.ClipPrimitive, String}(Compose.ClipPrimitive{Tuple{Measures.AbsoluteLength, Measures.AbsoluteLength}}(Tuple{Measures.AbsoluteLength, Measures.AbsoluteLength}[(132.93166666666667mm, 10.611666666666665mm), (223.59999999999997mm, 10.611666666666665mm), (223.59999999999997mm, 131.7783333333333mm), (132.93166666666667mm, 131.7783333333333mm)]) => "img-bfe74735-4", Compose.ClipPrimitive{Tuple{Measures.AbsoluteLength, Measures.AbsoluteLength}}(Tuple{Measures.AbsoluteLength, Measures.AbsoluteLength}[(18.63166666666666mm, 10.611666666666679mm), (109.29999999999998mm, 10.611666666666679mm), (109.29999999999998mm, 133.11499999999998mm), (18.63166666666666mm, 133.11499999999998mm)]) => "img-bfe74735-370"), Tuple{Compose.FormPrimitive, String}[], Set{AbstractString}(), true, false, nothing, true, "img-bfe74735-723", false, 723, Set(AbstractString["/Users/jamesdoss-gollin/.julia/packages/Gadfly/OQ068/src/gadfly.js"]), Set(Tuple{AbstractString, AbstractString}[("Snap.svg", "Snap"), ("Gadfly", "Gadfly")]), AbstractString["fig.select(\"#img-bfe74735-5\")\n   .init_gadfly();", "fig.select(\"#img-bfe74735-27\")\n   .data(\"ilabel\", \"65RGBA{Float32}(0.0f0,0.0f0,0.0f0,1.0f0)\")\n.mouseenter(Gadfly.datatip_visible)\n.mouseleave(Gadfly.datatip_hidden)\n;", "fig.select(\"#img-bfe74735-32\")\n   .data(\"ilabel\", \"64RGBA{Float32}(0.0f0,0.0f0,0.0f0,1.0f0)\")\n.mouseenter(Gadfly.datatip_visible)\n.mouseleave(Gadfly.datatip_hidden)\n;", "fig.select(\"#img-bfe74735-37\")\n   .data(\"ilabel\", \"63RGBA{Float32}(0.0f0,0.0f0,0.0f0,1.0f0)\")\n.mouseenter(Gadfly.datatip_visible)\n.mouseleave(Gadfly.datatip_hidden)\n;", "fig.select(\"#img-bfe74735-42\")\n   .data(\"ilabel\", \"62RGBA{Float32}(0.0f0,0.0f0,0.0f0,1.0f0)\")\n.mouseenter(Gadfly.datatip_visible)\n.mouseleave(Gadfly.datatip_hidden)\n;", "fig.select(\"#img-bfe74735-47\")\n   .data(\"ilabel\", \"61RGBA{Float32}(0.0f0,0.0f0,0.0f0,1.0f0)\")\n.mouseenter(Gadfly.datatip_visible)\n.mouseleave(Gadfly.datatip_hidden)\n;", "fig.select(\"#img-bfe74735-52\")\n   .data(\"ilabel\", \"60RGBA{Float32}(0.0f0,0.0f0,0.0f0,1.0f0)\")\n.mouseenter(Gadfly.datatip_visible)\n.mouseleave(Gadfly.datatip_hidden)\n;", "fig.select(\"#img-bfe74735-57\")\n   .data(\"ilabel\", \"59RGBA{Float32}(0.0f0,0.0f0,0.0f0,1.0f0)\")\n.mouseenter(Gadfly.datatip_visible)\n.mouseleave(Gadfly.datatip_hidden)\n;", "fig.select(\"#img-bfe74735-62\")\n   .data(\"ilabel\", \"58RGBA{Float32}(0.0f0,0.0f0,0.0f0,1.0f0)\")\n.mouseenter(Gadfly.datatip_visible)\n.mouseleave(Gadfly.datatip_hidden)\n;", "fig.select(\"#img-bfe74735-67\")\n   .data(\"ilabel\", \"57RGBA{Float32}(0.0f0,0.0f0,0.0f0,1.0f0)\")\n.mouseenter(Gadfly.datatip_visible)\n.mouseleave(Gadfly.datatip_hidden)\n;"  …  "fig.select(\"#img-bfe74735-668\")\n   .data(\"ilabel\", \"10RGBA{Float32}(0.0f0,0.74736935f0,1.0f0,1.0f0)\")\n.mouseenter(Gadfly.datatip_visible)\n.mouseleave(Gadfly.datatip_hidden)\n;", "fig.select(\"#img-bfe74735-673\")\n   .data(\"ilabel\", \"9RGBA{Float32}(0.0f0,0.74736935f0,1.0f0,1.0f0)\")\n.mouseenter(Gadfly.datatip_visible)\n.mouseleave(Gadfly.datatip_hidden)\n;", "fig.select(\"#img-bfe74735-678\")\n   .data(\"ilabel\", \ ...
